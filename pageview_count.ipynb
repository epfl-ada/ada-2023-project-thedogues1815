# %%
import requests
import matplotlib.pyplot as plt
import pandas as pd
import json

##This is a function used to fetch the pageview count of wikipedia articles during covid

# %%
def fetch_pageview_count(language, articles):
    api_url = "https://wikimedia.org/api/rest_v1/metrics/pageviews/per-article/{project}/{access}/{agent}/{article}/{granularity}/{start}/{end}"

    params = {
        "project": f"{language}.wikipedia",   # Language-specific Wikipedia project
        "access": "all-access",
        "agent": "user",
        "granularity": "monthly",
        "start": "20180101",
        "end": "20230101"
    }

    headers = {
        "User-Agent": "WikiWackyNews"
    }

    pageviews_data = {}

    for article in articles:
        params["article"] = article

        # Make the API request
        response = requests.get(api_url.format(**params), headers=headers)
        
        # Access the data and save it as a dataframe
        if response.status_code == 200:
            data = response.json()
            item_list = data.get("items", [])
            
            if item_list:
                df = pd.DataFrame(item_list).copy()
                df['timestamp'] = pd.to_datetime(df['timestamp'], format='%Y%m%d%H')
                pageviews_data[article] = df
            else:
                print(f"No data available for {article}")
        else:
            print(f"Error fetching data for {article}. Status Code: {response.status_code}")

    return pageviews_data

# %%
# Example usage:
language = "fr"
articles_list = ["Covid-19", "Hydroxychloroquine"]
result = fetch_pageview_count(language, articles_list)

# result contains a dictionary where keys are article names and values are DataFrames with pageviews data.
print(result)
# Out:
# {'Covid-19':          project   article granularity  timestamp      access agent  views
# 0   fr.wikipedia  Covid-19     monthly 2020-02-01  all-access  user    779
# 1   fr.wikipedia  Covid-19     monthly 2020-03-01  all-access  user  17357
# 2   fr.wikipedia  Covid-19     monthly 2020-04-01  all-access  user   9684
# 3   fr.wikipedia  Covid-19     monthly 2020-05-01  all-access  user   4856
# 4   fr.wikipedia  Covid-19     monthly 2020-06-01  all-access  user   2714
# 5   fr.wikipedia  Covid-19     monthly 2020-07-01  all-access  user   2348
# 6   fr.wikipedia  Covid-19     monthly 2020-08-01  all-access  user   1971
# 7   fr.wikipedia  Covid-19     monthly 2020-09-01  all-access  user   2070
# 8   fr.wikipedia  Covid-19     monthly 2020-10-01  all-access  user   2649
# 9   fr.wikipedia  Covid-19     monthly 2020-11-01  all-access  user   2719
# 10  fr.wikipedia  Covid-19     monthly 2020-12-01  all-access  user   2408
# 11  fr.wikipedia  Covid-19     monthly 2021-01-01  all-access  user   2870
# 12  fr.wikipedia  Covid-19     monthly 2021-02-01  all-access  user   1917
# 13  fr.wikipedia  Covid-19     monthly 2021-03-01  all-access  user   2059
# 14  fr.wikipedia  Covid-19     monthly 2021-04-01  all-access  user   2369
# 15  fr.wikipedia  Covid-19     monthly 2021-05-01  all-access  user   1493
# 16  fr.wikipedia  Covid-19     monthly 2021-06-01  all-access  user   1224
# 17  fr.wikipedia  Covid-19     monthly 2021-07-01  all-access  user   1432
# 18  fr.wikipedia  Covid-19     monthly 2021-08-01  all-access  user   1357
# 19  fr.wikipedia  Covid-19     monthly 2021-09-01  all-access  user   1054
# 20  fr.wikipedia  Covid-19     monthly 2021-10-01  all-access  user   1036
# 21  fr.wikipedia  Covid-19     monthly 2021-11-01  all-access  user   1166
# 22  fr.wikipedia  Covid-19     monthly 2021-12-01  all-access  user   2787
# 23  fr.wikipedia  Covid-19     monthly 2022-01-01  all-access  user   3521
# 24  fr.wikipedia  Covid-19     monthly 2022-02-01  all-access  user    868
# 30  fr.wikipedia  Hydroxychloroquine     monthly 2020-07-01  all-access  user
# 31  fr.wikipedia  Hydroxychloroquine     monthly 2020-08-01  all-access  user
# 32  fr.wikipedia  Hydroxychloroquine     monthly 2020-09-01  all-access  user
# 33  fr.wikipedia  Hydroxychloroquine     monthly 2020-10-01  all-access  user
# 34  fr.wikipedia  Hydroxychloroquine     monthly 2020-11-01  all-access  user
# 35  fr.wikipedia  Hydroxychloroquine     monthly 2020-12-01  all-access  user
# 36  fr.wikipedia  Hydroxychloroquine     monthly 2021-01-01  all-access  user
# 37  fr.wikipedia  Hydroxychloroquine     monthly 2021-02-01  all-access  user
# 38  fr.wikipedia  Hydroxychloroquine     monthly 2021-03-01  all-access  user
# 39  fr.wikipedia  Hydroxychloroquine     monthly 2021-04-01  all-access  user
# 40  fr.wikipedia  Hydroxychloroquine     monthly 2021-05-01  all-access  user
# 41  fr.wikipedia  Hydroxychloroquine     monthly 2021-06-01  all-access  user
# 42  fr.wikipedia  Hydroxychloroquine     monthly 2021-07-01  all-access  user
# 43  fr.wikipedia  Hydroxychloroquine     monthly 2021-08-01  all-access  user
# 44  fr.wikipedia  Hydroxychloroquine     monthly 2021-09-01  all-access  user
# 45  fr.wikipedia  Hydroxychloroquine     monthly 2021-10-01  all-access  user
# 46  fr.wikipedia  Hydroxychloroquine     monthly 2021-11-01  all-access  user
# 47  fr.wikipedia  Hydroxychloroquine     monthly 2021-12-01  all-access  user
# 48  fr.wikipedia  Hydroxychloroquine     monthly 2022-01-01  all-access  user
# 49  fr.wikipedia  Hydroxychloroquine     monthly 2022-02-01  all-access  user
# 50  fr.wikipedia  Hydroxychloroquine     monthly 2022-03-01  all-access  user
# 51  fr.wikipedia  Hydroxychloroquine     monthly 2022-04-01  all-access  user
# 52  fr.wikipedia  Hydroxychloroquine     monthly 2022-05-01  all-access  user
# 53  fr.wikipedia  Hydroxychloroquine     monthly 2022-06-01  all-access  user
# 54  fr.wikipedia  Hydroxychloroquine     monthly 2022-07-01  all-access  user
# 55  fr.wikipedia  Hydroxychloroquine     monthly 2022-08-01  all-access  user
# 56  fr.wikipedia  Hydroxychloroquine     monthly 2022-09-01  all-access  user
# 57  fr.wikipedia  Hydroxychloroquine     monthly 2022-10-01  all-access  user
# 58  fr.wikipedia  Hydroxychloroquine     monthly 2022-11-01  all-access  user
# 59  fr.wikipedia  Hydroxychloroquine     monthly 2022-12-01  all-access  user
#
#      views
# 0      885
# 1      769
# 2      798
# 3      831
# 4      908
# 5      801
# 6      755
# 7      691
# 8      903
# 9     1013
# 10    1120
# 11    1190
# 12    1110
# 13    1139
# 14    1081
# 15    1111
# 16    1039
# 17    1018
# 18     845
# 19     880
# 20     962
# 21    1231
# 22    1037
# 23    1024
# 24    1213
# 25    2590
# 26  175549
# 27   71623
# 28   41864
# 29   19205
# 30   12259
# 31   13256
# 32   11676
# 33   13373
# 34   25025
# 35   16019
# 36   12435
# 37    6957
# 38    7885
# 39    8350
# 40    6585
# 41    7252
# 42   10355
# 43   11749
# 44    7412
# 45    5631
# 46    7235
# 47    9387
# 48   12259
# 49    4532
# 50    4575
# 51    3688
# 52    2974
# 53    2952
# 54    2756
# 55    2292
# 56    2780
# 57    3129
# 58    3832
# 59    2873  }
